# %% [markdown]
# ### Email tools

# %% [markdown]
# Startup

# %%
from pathlib import Path
from project import Project
from utils.io import load_json

config = load_json('config.json')
config['source'] = Path(config['source'])
config['project_folder'] = Path(config['project_folder'])
project = Project(**config)

# %% [markdown]
# Find org names in docs filtered by query

# %%
query = ['church']
query_label = query[0]
project.get_entities_from_relevant_docs(query, query_label=query_label, query_threshold=.25)
# Out:
#   0%|          | 0/82 [00:00<?, ?it/s]Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# 100%|██████████| 82/82 [01:54<00:00,  1.40s/it]

# %% [markdown]
# Search emails

# %%
query = 'food'
top_n = 10
project.query_docs(query, top_n)
# Out:
# RESULT 1:
# ---------
#
# Read to the very end. Have a peaceful and blessed week.
#
# SPECIAL GROCERY
#
# LIST
#
# Louise
#
# Redden, a poorly dressed lady with a look of
#
# defeat on her
#
# face, walked into a grocery
#
# store.
#
# She approached the owner of the store
#
# in a most humble manner and asked if he would let
#
# her
#
# charge a few groceries.
#
# She softly explained that
#
# her husband was very ill and unable to work, they
#
# had
#
# seven children and they needed food.
#
# John
#
# Longhouse, the grocer, scoffed at her and
#
# requested that
#
# she leave his store at once.
#
# Visualizing the family
#
# needs, she said: 'Please, sir! I will bring you
#
# the money
#
# just as soon as I can.'
#
# John told her he could not
#
# give her credit, since she did20not have a charge
#
# account
#
# at his store.
#
# Standing beside the counter was a
#
# customer who overheard the conversation between
#
# the two.
#
# The customer walked forward and told the grocer
#
# that he
#
# would stand good for whatever she needed for her
#
# family.
#
# The grocer said in a very reluctant voice, 'Do
#
# you have a
#
# grocery list?'
#
# Louise replied, 'Yes sir.' 'O.K' he
#
# said, 'put your grocery list on the scales and
#
# whatever
#
# your grocery list weighs, I will give you that
#
# amount in
#
# groceries.'
#
# Louise hesitated a moment with a bowed
#
# head, then she reached into her purse and took
#
# out a piece
#
# of paper and scribbled something on it. She then
#
# laid the
#
# piece of paper on the scale carefully with her
#
# head still
#
# bowed.
#
# The eyes of the grocer and the customer
#
# showed amazement when the scales went down and
#
# stayed
#
# down.
#
# The grocer, staring at the scales, turned
#
# slowly to the customer and said begrudgingly, 'I
#
# can't
#
# believe it.'
#
# The customer smiled and the grocer
#
# started putting the groceries on the other side
#
# of the
#
# scales. The scale did not balance so he continued
#
# to put
#
# more and more groceries on them until the scales
#
# would
#
# hold no more.
#
# The grocer stood there in utter
#
# disgust. Finally, he grabbed the piece of paper
#
# from the
#
# scales and looked at it with greater amazement.
#
# It
#
# was not a grocery list, it was a prayer, which
#
# said:
#
# 'Dear
#
# Lord, you know my needs and I am leaving this in
#
# your
#
# hands.'
#
# The
#
# grocer gave her the
#
# groceries that he had
#
# gathered and
#
# stood in stunned silence.
#
# Louise thanked him and
#
# left the store. The other customer handed a
#
# fifty-dollar
#
# bill to the grocer and said; 'It was worth every
#
# penny of
#
# it. Only God Knows how much a prayer weighs.'
#
# THE
#
# POWER: When you receive this, say a prayer.
#
# That's all you
#
# have to do.
#
# Just stop right now, and say a prayer
#
# of thanks for your own good fortune. Then please
#
# send
#
# this to all your friends and relatives.
#
# I believe
#
# if you will send this testimony out with prayer
#
# in faith,
#
# you will receive what you need God to do in your
#
# and your
#
# families' life .
#
# So
#
# dear heart, trust
#
# God to heal the sick, provide food for the
#
# hungry,
#
# clothes and shelter for those=2
#
# 0that don't have as
#
# we do.
#
# Amen & Amen
#
# Don't
#
# break this, please!
#
# Prayer is one of the best free
#
# gifts we receive.
#
# There
#
# is no cost but a lot of rewards.
#
# May you always walk
#
# with Angels
#
# God Bless!
#
# My
#
# prayer for you today:
#
# The eyes beholding this
#
# message shall not behold evil, the hands that
#
# will send
#
# this message to others shall not labor in vain,
#
# the mouth
#
# saying Amen to this prayer shall laugh forever.
#
# Remain in
#
# God's love as you send this prayer to everybody
#
# on your
#
# list. Have a lovely journey of life! Trust in the
#
# Lord with all your heart and He will never fail
#
# you
#
# because He is Awesome!
#
# If you truly need a
#
# blessing, continue reading this
#
# email:
#
# Heavenly
#
# Father, most Gracious and Loving God, I pray to
#
# you that
#
# you abundantly bless my family and me. I know
#
# that you
#
# recognize, that a family is more than just a
#
# mother,
#
# father, sister, brother, husband and wife, but
#
# all who
#
# believe and trust in you. Father, I send up a
#
# prayer
#
# request for blessings for not only the person who
#
# sent this to me, but for me and all that I have
#
# forwarded
#
# this message on to. And that the power of joined
#
# prayer by
#
# those who believe and trust in you is more
#
# powerful than
#
# anything. I thank you in advance for your
#
# blessings.
#
# Father God, deliver the person reading
#
# this right now from debt and debt burdens.
#
# Release your
#
# Godly wisdom that I may be a good steward over
#
# all that
#
# You have given me Father, for I know how
#
# wonderful and
#
# mighty you are and how if we just obey you and
#
# walk in
#
# your word and have the faith of a mustard seed
#
# that
#
# you will pour out blessings. I thank you now Lord
#
# for the
#
# recent blessings I have received and for the
#
# blessings yet
#
# to come because I know you are not done with me
#
# yet. In
#
# Jesus name, I pray, Amen
#
# TAKE
#
# 60 SECONDS and send this on quickly and with in
#
# hours, you
#
# will have caused a multitude of people to pray to
#
# God for
#
# each other. Peace and
#
# Blessings...
#
# God Bless you,
# Dennis Collins
# Bikers for Christ
# www.grnwdfam@prodigy.net
#
# --------------------------------------------------------------------------------
#
# Disclaimer Confidentiality Notice: This e-mail, and any attachments
# and/or documents linked to this email, are intended for the
# addressee and may contain information that is privileged,
# confidential, proprietary, or otherwise protected by law. Any
# dissemination, distribution, or copying is prohibited. This
# notice serves as a confidentiality marking for the purpose of
# any confidentiality or nondisclosure agreement. If you have
# received this communication in error, please contact the
# original sender.
#
# ===========================================================================
#
# RESULT 2:
# ---------
#
# I can bring the dinner rolls – wheat!
#
# -----Original Message-----
# From: Steve DeBuhr [mailto:sdb750@embarqmail.com]
# Sent: Thursday, June 18, 2009 3:04 PM
# To: 'Gary Hubbard'; 'Brian & Sherri Hartman'; dcaister@sanctuarycares.org; 'Toby
# Matherly'; 'Greg Lightfoot'; 'Jon Sturm'; 'Larry & Paige Craigie'
# Subject: RE: Elder Retreat- Email #2---the Food Email
#
# As it stands:
#
# Dinner rolls___________________________
#
# 2-Liters: Greg
#
# During the Meeting snacks: Toby
#
# Bagels: Gary
#
# Donuts/pastry ________________________________________________
#
# --------------------------------------------------------------------------------
#
# From: Gary Hubbard [mailto:ghubbard@sanctuarycares.org]
# Sent: Thursday, June 18, 2009 3:01 PM
# To: 'Steve DeBuhr'; 'Brian & Sherri Hartman'; dcaister@sanctuarycares.org; 'Toby
# Matherly'; 'Greg Lightfoot'; 'Jon Sturm'; 'Larry & Paige Craigie'
# Subject: RE: Elder Retreat- Email #2---the Food Email
#
# Steve,
#
# I can bring bagels!
#
# Gary
#
# -----Original Message-----
# From: Steve DeBuhr [mailto:sdb750@embarqmail.com]
# Sent: Thursday, June 18, 2009 9:25 AM
# To: 'Steve DeBuhr'; 'Brian & Sherri Hartman'; 'Gary Hubbard';
# dcaister@sanctuarycares.org; 'Toby Matherly'; 'Greg Lightfoot'; 'Jon Sturm';
# 'Larry & Paige Craigie'
# Subject: Elder Retreat- Email #2---the Food Email
#
# Guys,
#
# I need someone to bring the following:
#
# Dinner rolls___________________________
#
# 2-Liters ______________________________
#
# During the Meeting snacks__________________________________
#
# Bagels _______________________________________________
#
# Donuts/pastry ________________________________________________
#
# Gracias
#
# ===========================================================================
#
# RESULT 3:
# ---------
#
# Hello Friends,
#
# (I am sending the original information below because we have added a few
# people/small group leaders to the e-mail list.)
#
# We have decided to change the menu for the homeless outreach. We are going with
# scrambled eggs and brownies for dessert. We need people to:
#
# 1. make 4 dozen scrambled eggs adding meat only if you want to ( you can do
#  this the night before and warm it up Sat.) The food will stay warm if you
#  put in a cooler to transport. Use 9 x 13 or larger pans.
#
#  2. make 16 pan of brownies, cut, ready to serve. I have about 7 pans of
#  brownies accounted for so far. (thanks in advance!)
#
# Location: Roberts Park United Methodist; Corner of Delaware and Vermont; 401 N
# Delaware St,
#
# Indianapolis, IN 46204 (really close to Mass Ave- for all you hipsters)
#
# Original information
#
# The Wallman small group is doing an outreach of feeding the homeless on Sat.
# Sept. 5th, LABOR DAY WEEKEND. I will explain the outreach and then our needs.
# (If you are receiving this you have either helped in the past or we are asking
# you to pass the information along to your small group to see if anyone can
# help.)
#
# We are teaming up again this year with Nathan from Grace Assembly to feed 200
# homeless people. Nathan has been doing this every Sat. morning for several
# years. Last year he was feeding 100 people so you can see the need has jumped
# for him. Nathan has a system down (including a truck) where we provide the food
# and he provides the serving utensils, bread, and drinks. This works best if we
# all fix the same food.
#
# Nathan's truck needs about 5-8 people to serve but our extra people walk around
# and talk with those we are serving. We do this as a Dad/Man plus your
# teenager(the age is up to the parent) if you want kind of thing. So yes,
# generally the women are cooking and the men are taking the food to serve. We
# welcome whomever wants to come!!
#
# You can either bring food and serve it or make food and drop it off EARLY Sat.
# at someone else's home to take it for you. We would appreciate either way and
# the Wallman's live off Whiteland Road.
#
# We meet downtown at 7:15 am and start serving at 7:30. I will give more detail
# later.
#
# Thanks so much for getting the word out and please pray that God will provide
# for this.
#
# Feel free to contact me with any questions.
#
# Diana DeBuhr
# 422-5595
# 496-4109 cell
#
# ===========================================================================
#
# RESULT 4:
# ---------
#
# Guys,
#
# I need someone to bring the following:
#
# Dinner rolls___________________________
#
# 2-Liters ______________________________
#
# During the Meeting snacks__________________________________
#
# Bagels _______________________________________________
#
# Donuts/pastry ________________________________________________
#
# Gracias
#
# ===========================================================================
#
# RESULT 5:
# ---------
#
# As it stands:
#
# Dinner rolls___________________________
#
# 2-Liters: Greg
#
# During the Meeting snacks: Toby
#
# Bagels: Gary
#
# Donuts/pastry ________________________________________________
#
# --------------------------------------------------------------------------------
#
# From: Gary Hubbard [mailto:ghubbard@sanctuarycares.org]
# Sent: Thursday, June 18, 2009 3:01 PM
# To: 'Steve DeBuhr'; 'Brian & Sherri Hartman'; dcaister@sanctuarycares.org; 'Toby
# Matherly'; 'Greg Lightfoot'; 'Jon Sturm'; 'Larry & Paige Craigie'
# Subject: RE: Elder Retreat- Email #2---the Food Email
#
# Steve,
#
# I can bring bagels!
#
# Gary
#
# -----Original Message-----
# From: Steve DeBuhr [mailto:sdb750@embarqmail.com]
# Sent: Thursday, June 18, 2009 9:25 AM
# To: 'Steve DeBuhr'; 'Brian & Sherri Hartman'; 'Gary Hubbard';
# dcaister@sanctuarycares.org; 'Toby Matherly'; 'Greg Lightfoot'; 'Jon Sturm';
# 'Larry & Paige Craigie'
# Subject: Elder Retreat- Email #2---the Food Email
#
# Guys,
#
# I need someone to bring the following:
#
# Dinner rolls___________________________
#
# 2-Liters ______________________________
#
# During the Meeting snacks__________________________________
#
# Bagels _______________________________________________
#
# Donuts/pastry ________________________________________________
#
# Gracias
#
# ===========================================================================
#
# RESULT 6:
# ---------
#
# Hello Friends,
#
# The Wallman small group is doing an outreach of feeding the homeless on Sat.
# Sept. 5th, LABOR DAY WEEKEND. I will explain the outreach and then our needs.
# (If you are receiving this you have either helped in the past or we are asking
# you to pass the information along to your small group to see if anyone can
# help.)
#
# We are teaming up again this year with Nathan from Grace Assembly to feed 200
# homeless people. Nathan has been doing this every Sat. morning for several
# years. Last year he was feeding 100 people so you can see the need has jumped
# for him. Nathan has a system down (including a truck) where we provide the food
# and he provides the serving utensils, bread, and drinks. This works best if we
# all fix the same food. I know it sounds crazy, but Nathan said they love
# lasagna. This is something we have done in the past and either bought frozen
# ones to cook or you can make it the night before and cook early Sat. am. We
# also have provided brownies to go with it.
#
# We need at 20 lasagnas (I know-don't freak out, I'm trusting God to provide).
# We need about 16 pans (9X13) of brownies, already cut
#
# Nathan's truck needs about 5-8 people to serve but our extra people walk around
# and talk with those we are serving. We do this as a Dad/Man plus your
# teenager(the age is up to the parent) if you want kind of thing. So yes,
# generally the women are cooking and the men are taking the food to serve.
#
# You can either bring food and serve it or make food and drop it off EARLY Sat.
# at someone else's home to take it for you. We would appreciate either way and
# the Wallman's live off Whiteland Road.
#
# We meet downtown at 7:15 am and start serving at 7:30. I will give more detail
# later.
#
# Thanks so much for getting the word out and please pray that God will provide
# for this.
#
# Feel free to contact me with any questions.
#
# Diana DeBuhr
# 422-5595
# 496-4109 cell
#
# ===========================================================================
#
# RESULT 7:
# ---------
#
# Steve,
#
# I can bring bagels!
#
# Gary
#
# -----Original Message-----
# From: Steve DeBuhr [mailto:sdb750@embarqmail.com]
# Sent: Thursday, June 18, 2009 9:25 AM
# To: 'Steve DeBuhr'; 'Brian & Sherri Hartman'; 'Gary Hubbard';
# dcaister@sanctuarycares.org; 'Toby Matherly'; 'Greg Lightfoot'; 'Jon Sturm';
# 'Larry & Paige Craigie'
# Subject: Elder Retreat- Email #2---the Food Email
#
# Guys,
#
# I need someone to bring the following:
#
# Dinner rolls___________________________
#
# 2-Liters ______________________________
#
# During the Meeting snacks__________________________________
#
# Bagels _______________________________________________
#
# Donuts/pastry ________________________________________________
#
# Gracias
#
# ===========================================================================
#
# RESULT 8:
# ---------
#
# Dear Care Group Leaders,
#
# Our annual EASTER egg hunt has consistently been one of the most successful
# outreach events at Sanctuary. We have blessed many guests and neighbors by
# hosting this community outreach in year’s past. We are praying for even a bigger
# turnout this year.
#
# The challenge and opportunity that lies before us is getting everyone on-board.
# That’s where I need your help. Please prayerfully consider how your group or
# family can participate. There are many opportunities to serve.
#
# We still need helpers in the following areas:
#
# * Welcome table
#  * Refreshment table
#  * Games: skeet ball, soccer boy, ball maze, ladder, ping pong toss, corn hole,
#  and parachute.
#  * Hiding eggs
#  * Face painting
#  * Balloon animals
#
# Additionally, we need commitments for whole care groups to step up with the
# following tasks:
#
# * Church / egg decorating & set-up
#  * Church / egg clean-up
#  * Egg fillers (fill plastic eggs with candy and Bible verse)
#
# Some food is also needed: hot dogs, buns, potato salad, chips, condiments, ice.
# All of those food items can / should be at the church in advance.
#
# Most of all we need ‘500’ more plastic eggs and small preferably wrapped candy.
#
# Please pray for this event with your care group and sign-up to serve our own
# members and our community. We will need commitments for most of the above listed
# items, tasks by this Sunday. The Easter Egg Hunt is less than two weeks away.
#
# Pray also about who you can invite to the event keeping in mind that Easter will
# be the following day. This event would be a good introduction for those you plan
# to invite to church on Easter Sunday.
#
# Grace and Blessings Philippians
# 4:13
#
# Pastor Gary
#
# ===========================================================================
#
# RESULT 9:
# ---------
#
# Hey Steve are the new elder candidates attending the retreat?
#
# -----Original Message-----
# From: Steve DeBuhr [mailto:sdb750@embarqmail.com]
# Sent: Thursday, June 18, 2009 3:04 PM
# To: 'Gary Hubbard'; 'Brian & Sherri Hartman'; dcaister@sanctuarycares.org; 'Toby
# Matherly'; 'Greg Lightfoot'; 'Jon Sturm'; 'Larry & Paige Craigie'
# Subject: RE: Elder Retreat- Email #2---the Food Email
#
# As it stands:
#
# Dinner rolls___________________________
#
# 2-Liters: Greg
#
# During the Meeting snacks: Toby
#
# Bagels: Gary
#
# Donuts/pastry ________________________________________________
#
# --------------------------------------------------------------------------------
#
# From: Gary Hubbard [mailto:ghubbard@sanctuarycares.org]
# Sent: Thursday, June 18, 2009 3:01 PM
# To: 'Steve DeBuhr'; 'Brian & Sherri Hartman'; dcaister@sanctuarycares.org; 'Toby
# Matherly'; 'Greg Lightfoot'; 'Jon Sturm'; 'Larry & Paige Craigie'
# Subject: RE: Elder Retreat- Email #2---the Food Email
#
# Steve,
#
# I can bring bagels!
#
# Gary
#
# -----Original Message-----
# From: Steve DeBuhr [mailto:sdb750@embarqmail.com]
# Sent: Thursday, June 18, 2009 9:25 AM
# To: 'Steve DeBuhr'; 'Brian & Sherri Hartman'; 'Gary Hubbard';
# dcaister@sanctuarycares.org; 'Toby Matherly'; 'Greg Lightfoot'; 'Jon Sturm';
# 'Larry & Paige Craigie'
# Subject: Elder Retreat- Email #2---the Food Email
#
# Guys,
#
# I need someone to bring the following:
#
# Dinner rolls___________________________
#
# 2-Liters ______________________________
#
# During the Meeting snacks__________________________________
#
# Bagels _______________________________________________
#
# Donuts/pastry ________________________________________________
#
# Gracias
#
# ===========================================================================
#
# RESULT 10:
# ---------
#
# Good Morning, Everyone;
#
# The July Financials are attached. I have also placed a hard copy in your mail
# boxes.
#
# Enjoy!
#
# Ann
#
# ===========================================================================

# %%
project.doc_ref.df
